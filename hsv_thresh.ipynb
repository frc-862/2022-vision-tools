# %% [markdown]
# # Notebook for adjusting HSV threshold on collected images
# (Very much does not work right now)

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.widgets import RangeSlider, Button

# Probably vestigial
def nothing(x):
    pass


# Get current dir
base_path = os.getcwd()

# %%
maxHue = 179
maxValue = maxSaturation = 255

hue_slider_ax = plt.axes([0.20, 0.1, 0.60, 0.03])
hueSlider = RangeSlider(hue_slider_ax, "Threshold", 0, maxHue)

# slider_ax = plt.axes([0.20, 0.1, 0.60, 0.03])
# slider = RangeSlider(slider_ax, "Threshold", img.min(), img.max())
# 
# slider_ax = plt.axes([0.20, 0.1, 0.60, 0.03])
# slider = RangeSlider(slider_ax, "Threshold", img.min(), img.max())
for my_path, my_subdirs, my_files in os.walk(base_path):
    for my_file in my_files:
        if(my_file.endswith(".jpg")):            
            # Concatenate strings so we can access images in subdirs
            image = cv2.imread(my_path + "/" + my_file)
            

plt.imshow(image)

            # Set minimum and maximum HSV values to display
            # lower = np.array([hMin, sMin, vMin])
            # upper = np.array([hMax, sMax, vMax])

            # Convert to HSV format and color threshold
            # hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
            # mask = cv2.inRange(hsv, lower, upper)
            # result = cv2.bitwise_and(image, image, mask=mask)
plt.show()
# Out:
# c:\Users\Bob\Documents\GitHub\limelight-tools
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\hooks
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\info
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\logs
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\logs\refs
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\logs\refs\heads
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\logs\refs\remotes
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\logs\refs\remotes\origin
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\07
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\17
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\37
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\3c
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\44
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\72
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\85
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\c8
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\cc
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\d5
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\e1
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\fa
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\info
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\objects\pack
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\refs
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\refs\heads
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\refs\remotes
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\refs\remotes\origin
# c:\Users\Bob\Documents\GitHub\limelight-tools\.git\refs\tags
# c:\Users\Bob\Documents\GitHub\limelight-tools\.ipynb_checkpoints
# c:\Users\Bob\Documents\GitHub\limelight-tools\samples
# c:\Users\Bob\Documents\GitHub\limelight-tools\snapshots
# c:\Users\Bob\Documents\GitHub\limelight-tools\snapshots\limelight
# c:\Users\Bob\Documents\GitHub\limelight-tools\snapshots\limelight\snapshots
# c:\Users\Bob\Documents\GitHub\limelight-tools\snapshots\limelight\static
# c:\Users\Bob\Documents\GitHub\limelight-tools\snapshots\limelight\static\css
# c:\Users\Bob\Documents\GitHub\limelight-tools\snapshots\limelight\static\js
