# %% [markdown]
# # Vision calibration
# offloads points on img to CSV file.

# %%
# All the imports
import PIL
import cv2
import os
import numpy as np

# Uses tk as gui backend 
import matplotlib
matplotlib.use('TkAgg')

import matplotlib.pyplot as plt

# %%
def color_distance (image, color):
    
    # Allocate a return image - single layer, the distance
    ri = np.zeros( (image.shape[0],image.shape[1]), dtype=np.float )
    
    for r in range(0,image.shape[0]):
        for c in range(0,image.shape[1]):
            ri[r][c] = np.sqrt(np.sum(np.power(image[r][c]-color,2)))
            
    # Return the image
    return ri


def color_correlation ( image, color ):
    
    # Allocate a return image - single layer, the distance
    ri = np.zeros( (image.shape[0],image.shape[1]), dtype=np.float )
    
    corr_vec = color-np.mean(color)
    scalar = np.linalg.norm(corr_vec)
    corr_vec = (1.0/scalar)*corr_vec
    
    for r in range(0,image.shape[0]):
        for c in range(0,image.shape[1]):
            loc_vec = image[r][c]-np.mean(image[r][c])
            scalar = np.linalg.norm(loc_vec)
            loc_vec = (1.0/scalar)*loc_vec
            
            ri[r][c] = np.sum(np.multiply(loc_vec,corr_vec))
            
    # Return the image
    return ri


if __name__ == "__main__":
    
    
    base_path = os.getcwd()
    print("Current base path is " + base_path) 
    
    images_total = 0
    
    # Make sure we don't overwrite a previous attempt (incase there is good crap in it and there was an error)
    try_number = 0
    done = False
    while not(done):
        output_filename = os.path.join(base_path,'truth_'+str(try_number)+'.csv')
        if os.path.exists(output_filename):
            try_number += 1
        else:
            done = True
    
    # Open a file to write to
    with open(output_filename, 'w') as f:
        
        # Walk through all the files and find images to display/process
        for my_path, my_subdirs, my_files in os.walk(base_path):
            # Process each file in each directory
            for my_file in my_files:
                
                if (my_file.endswith(".jpg")):
                    images_total += 1
                    
                    temp_string = os.path.join(my_path,my_file)
                    f.write(temp_string[len(base_path)+1:]) # Strip the base path off to allow sharing of data files
                    f.write(",")
                    
                    in_image = plt.imread(os.path.join(my_path,my_file))
                    
                    plt.figure(1)
                    plt.clf()
                    plt.imshow(in_image)
                    
                    if (False):
                        #color_dist = color_distance(in_image,np.array([0,1,0]))
                        color_dist = color_correlation(in_image,np.array([0,1,0]))
        
                        plt.figure(2)
                        plt.clf()
                        plt.imshow(color_dist,cmap='hot')
                    
                    plt.draw()
                    plt.show()
                    plt.pause(0.1)
    
                    # BIG ASSUMPTION - WE FORCE THE USER OF THIS TOOL TO FIND 5 BOXES
                    # BIG ASSUMPTION #2 - THE BOXES ARE FOUND LEFT TO RIGHT
                    # BIG ASSUMPTION #3 - first click on a box is upper left (UL) and the second is lower right (LR)
                    # BIG ASSUMPTION #4 - clicked box spans all of the detectable energy for a reflected target
                    
                    v = plt.ginput(10,timeout=0)
                    for index in range(10):
                        f.write(str(v[index])+",")
                    f.write("\n")
    
    # EXAMPLE OUTPUT LINE:
    # 220in/debug5_exposure-10.png,(306.1321361922536, 430.16001447233117),(309.78830407129533, 432.44511939673225),(315.27255588985804, 428.7889515176905),(322.5848916479416, 431.0740564420916),(330.8112693757855, 427.8749095479301),(338.58062611874936, 431.5310774269718),(346.3499828617131, 427.8749095479301),(353.2052976349165, 430.6170354572114),(359.60359142323955, 430.16001447233117),(364.1738012720418, 433.35916136649274),
    # PROCESSING PROGRAM NEEDS TO BE ABLE TO READ AND PROCESS THIS INFO
    
    print("Total images:  "+str(images_total))
# Out:
# Current base path is /home/bob/Code/vision-tools
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/blocking_input.py:93, in BlockingInput.__call__(self, n, timeout)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=90'>91</a> try:
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=91'>92</a>     # Start event loop.
# ---> <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=92'>93</a>     self.fig.canvas.start_event_loop(timeout=timeout)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=93'>94</a> finally:  # Run even on exception like ctrl-c.
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=94'>95</a>     # Disconnect the callbacks.
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:2407, in FigureCanvasBase.start_event_loop(self, timeout)
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/backend_bases.py?line=2405'>2406</a> while self._looping and counter * timestep < timeout:
# -> <a href='file:///usr/lib/python3/dist-packages/matplotlib/backend_bases.py?line=2406'>2407</a>     self.flush_events()
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/backend_bases.py?line=2407'>2408</a>     time.sleep(timestep)
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py:390, in FigureCanvasTk.flush_events(self)
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=387'>388</a> def flush_events(self):
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=388'>389</a>     # docstring inherited
# --> <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=389'>390</a>     self._master.update()
#
# File /usr/lib/python3.9/tkinter/__init__.py:1314, in Misc.update(self)
#    <a href='file:///usr/lib/python3.9/tkinter/__init__.py?line=1312'>1313</a> """Enter event loop until all pending events have been processed by Tcl."""
# -> <a href='file:///usr/lib/python3.9/tkinter/__init__.py?line=1313'>1314</a> self.tk.call('update')
#
# TclError: can't invoke "update" command: application has been destroyed
#
# During handling of the above exception, another exception occurred:
#
# TclError                                  Traceback (most recent call last)
# /home/bob/Code/vision-tools/vision-calibration.ipynb Cell 3' in <cell line: 35>()
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=83'>84</a> plt.pause(0.1)
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=85'>86</a> # BIG ASSUMPTION - WE FORCE THE USER OF THIS TOOL TO FIND 5 BOXES
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=86'>87</a> # BIG ASSUMPTION #2 - THE BOXES ARE FOUND LEFT TO RIGHT
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=87'>88</a> # BIG ASSUMPTION #3 - first click on a box is upper left (UL) and the second is lower right (LR)
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=88'>89</a> # BIG ASSUMPTION #4 - clicked box spans all of the detectable energy for a reflected target
# ---> <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=90'>91</a> v = plt.ginput(10,timeout=0)
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=91'>92</a> for index in range(10):
#      <a href='vscode-notebook-cell:/home/bob/Code/vision-tools/vision-calibration.ipynb#ch0000002?line=92'>93</a>     f.write(str(v[index])+",")
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2383, in ginput(n, timeout, show_clicks, mouse_add, mouse_pop, mouse_stop)
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2377'>2378</a> @_copy_docstring_and_deprecators(Figure.ginput)
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2378'>2379</a> def ginput(
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2379'>2380</a>         n=1, timeout=30, show_clicks=True,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2380'>2381</a>         mouse_add=MouseButton.LEFT, mouse_pop=MouseButton.RIGHT,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2381'>2382</a>         mouse_stop=MouseButton.MIDDLE):
# -> <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2382'>2383</a>     return gcf().ginput(
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2383'>2384</a>         n=n, timeout=timeout, show_clicks=show_clicks,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2384'>2385</a>         mouse_add=mouse_add, mouse_pop=mouse_pop,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/pyplot.py?line=2385'>2386</a>         mouse_stop=mouse_stop)
#
# File /usr/lib/python3/dist-packages/matplotlib/figure.py:2453, in Figure.ginput(self, n, timeout, show_clicks, mouse_add, mouse_pop, mouse_stop)
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2403'>2404</a> """
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2404'>2405</a> Blocking call to interact with a figure.
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2405'>2406</a>
#    (...)
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2446'>2447</a> manager) selects a point.
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2447'>2448</a> """
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2448'>2449</a> blocking_mouse_input = BlockingMouseInput(self,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2449'>2450</a>                                           mouse_add=mouse_add,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2450'>2451</a>                                           mouse_pop=mouse_pop,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2451'>2452</a>                                           mouse_stop=mouse_stop)
# -> <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2452'>2453</a> return blocking_mouse_input(n=n, timeout=timeout,
#    <a href='file:///usr/lib/python3/dist-packages/matplotlib/figure.py?line=2453'>2454</a>                             show_clicks=show_clicks)
#
# File /usr/lib/python3/dist-packages/matplotlib/blocking_input.py:267, in BlockingMouseInput.__call__(self, n, timeout, show_clicks)
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=264'>265</a> self.clicks = []
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=265'>266</a> self.marks = []
# --> <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=266'>267</a> BlockingInput.__call__(self, n=n, timeout=timeout)
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=267'>268</a> return self.clicks
#
# File /usr/lib/python3/dist-packages/matplotlib/blocking_input.py:96, in BlockingInput.__call__(self, n, timeout)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=92'>93</a>     self.fig.canvas.start_event_loop(timeout=timeout)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=93'>94</a> finally:  # Run even on exception like ctrl-c.
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=94'>95</a>     # Disconnect the callbacks.
# ---> <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=95'>96</a>     self.cleanup()
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=96'>97</a> # Return the events in this case.
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=97'>98</a> return self.events
#
# File /usr/lib/python3/dist-packages/matplotlib/blocking_input.py:256, in BlockingMouseInput.cleanup(self, event)
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=253'>254</a>         mark.remove()
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=254'>255</a>     self.marks = []
# --> <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=255'>256</a>     self.fig.canvas.draw()
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=256'>257</a> # Call base class to remove callbacks.
#     <a href='file:///usr/lib/python3/dist-packages/matplotlib/blocking_input.py?line=257'>258</a> BlockingInput.cleanup(self)
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py:10, in FigureCanvasTkAgg.draw(self)
#       <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py?line=7'>8</a> def draw(self):
#       <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py?line=8'>9</a>     super(FigureCanvasTkAgg, self).draw()
# ---> <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py?line=9'>10</a>     _backend_tk.blit(self._tkphoto, self.renderer._renderer, (0, 1, 2, 3))
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/backend_tkagg.py?line=10'>11</a>     self._master.update_idletasks()
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py:75, in blit(photoimage, aggimage, offsets, bbox)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=72'>73</a>     bboxptr = (x1, x2, y1, y2)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=73'>74</a> else:
# ---> <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=74'>75</a>     photoimage.blank()
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=75'>76</a>     bboxptr = (0, width, 0, height)
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=76'>77</a> _tkagg.blit(
#      <a href='file:///usr/lib/python3/dist-packages/matplotlib/backends/_backend_tk.py?line=77'>78</a>     photoimage.tk.interpaddr(), str(photoimage), dataptr, offsets, bboxptr)
#
# File /usr/lib/python3.9/tkinter/__init__.py:4068, in PhotoImage.blank(self)
#    <a href='file:///usr/lib/python3.9/tkinter/__init__.py?line=4065'>4066</a> def blank(self):
#    <a href='file:///usr/lib/python3.9/tkinter/__init__.py?line=4066'>4067</a>     """Display a transparent image."""
# -> <a href='file:///usr/lib/python3.9/tkinter/__init__.py?line=4067'>4068</a>     self.tk.call(self.name, 'blank')
#
# TclError: invalid command name "pyimage11"
